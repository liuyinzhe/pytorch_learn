# %% [markdown]
# # 手写数字识别卷积神经网络

# %%
# 导入所需要的包，请保证torchvision已经在你的环境中安装好
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torchvision.datasets as dsets
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
# Hyper Parameters 
image_size = 28  #图像的总尺寸28*28
num_classes = 10  #标签的种类数；数字1-10
num_epochs = 20  #训练的总循环周期
batch_size = 64  # 拆分次数
learning_rate = 0.001  # 梯度改变速度

# 加载MINIST数据，如果没有下载过，就会在当前路径下新建/data子目录，并把文件存放其中

train_dataset = dsets.MNIST(root='./data',  #文件存放路径
                            train=True,   #提取训练集
                            transform=transforms.ToTensor(),  #将图像转化为Tensor
                            download=True)

test_dataset = dsets.MNIST(root='./data', 
                           train=False, 
                           transform=transforms.ToTensor())

# 训练数据集的加载器，自动将数据分割成batch，顺序随机打乱
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)
# 测试数据集的加载器，自动将数据分割成batch
permutes = np.random.permutation(range(len(test_dataset)))  # range 数字范围,打乱后就是打乱的索引编号
indices_val = permutes[:5000]
indices_test = permutes[5000:]
sampler_val = torch.utils.data.sampler.SubsetRandomSampler(indices_val)
sampler_test = torch.utils.data.sampler.SubsetRandomSampler(indices_test)
validation_loader = torch.utils.data.DataLoader(dataset =train_dataset,
                                                batch_size = batch_size,
                                                shuffle = False,
                                                sampler = sampler_val
                                               )
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False,
                                          sampler = sampler_test
                                         )

# %%
#定义卷积神经网络：4和8为人为指定的两个卷积层的厚度
depth = [4, 8] # 第一层卷积输入通道为1，输出为4， 第二层，的输入则为4，输出为8
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        # 输入图像是 灰度图像，只有一种颜色，所以 输入通道(特征) 为1； padding 用于保证卷积后，整体图像矩阵不缩小
        # 卷积，特征弥散，卷积核(局部特征)在图像中强化对应特征，弥散非对应卷积核，1个卷积核形成一个所谓的厚度，就是一个局部特征强化显示
        self.conv1 = nn.Conv2d(1, 4, 5, padding = 2) #输入通道为1，输出通道为4，窗口大小为5，padding为2
        # 池化，特征粒度提取，缩小图片，寻找关键特征
        self.pool = nn.MaxPool2d(2, 2) #一个窗口为2*2的pooling运算
        # 第二次卷积，强化每个厚度(强化后特征)
        self.conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2) #第二层卷积，输入通道为depth[0], 输出通道为depth[1]，窗口wei15，padding为2
        # 线性映射到512
        self.fc1 = nn.Linear(image_size // 4 * image_size // 4 * depth[1] , 512) #一个线性连接层，输入尺寸为最后一层立方体的平铺，输出层512个节点
        # 线性映射512到分类
        self.fc2 = nn.Linear(512, num_classes) #最后一层线性分类单元，输入为分类

    def forward(self, x):
        #神经网络完成一步前馈运算的过程，从输入到输出
        # 卷积激活，非线性转化，增加更多特征识别维度
        x = F.relu(self.conv1(x))
        # 池化
        x = self.pool(x)
        # 第二次卷积激活
        x = F.relu(self.conv2(x))
        # 池化
        x = self.pool(x)
        # 将立体的Tensor全部转换成一维的Tensor。两次pooling操作，所以图像维度减少了1/4
        x = x.view(-1, image_size // 4 * image_size // 4 * depth[1])
        # 线性映射激活
        x = F.relu(self.fc1(x)) #全链接，激活函数
        # 一定概率丢掉神经网络，避免过拟合，增加模型泛化性
        x = F.dropout(x, training=self.training) #以默认为0.5的概率对这一层进行dropout操作
        # 线性映射512到分类
        x = self.fc2(x) #全链接，激活函数
        x = F.log_softmax(x, dim = 1) #log_softmax可以理解为概率对数值
        return x
    
    def retrieve_features(self, x):
        #提取卷积神经网络的特征图的函数，返回feature_map1, feature_map2为前两层卷积层的特征图
        feature_map1 = F.relu(self.conv1(x))
        x = self.pool(feature_map1)
        feature_map2 = F.relu(self.conv2(x))
        return (feature_map1, feature_map2)

# %%
def rightness(predictions, labels):
    """计算预测错误率的函数，其中predictions是模型给出的一组预测结果，batch_size行10列的矩阵，labels是数据之中的正确答案"""
    pred = torch.max(predictions.data, 1)[1] # 对于任意一行（一个样本）的输出值的第1个维度，求最大，得到每一行的最大元素的下标
    rights = pred.eq(labels.data.view_as(pred)).sum() #将下标与labels中包含的类别进行比较，并累计得到比较正确的数量
    return rights, len(labels) #返回正确的数量和这一次一共比较了多少元素
net = ConvNet() #新建一个卷积神经网络的实例

criterion = nn.CrossEntropyLoss() #Loss函数的定义
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9) #定义优化器

record = [] #记录准确率等数值的容器
weights = [] #每若干步就记录一次卷积核

#开始训练循环
for epoch in range(num_epochs):
    
    train_rights = [] #记录训练数据集准确率的容器
    for batch_idx, (data, target) in enumerate(train_loader):  #针对容器中的每一个批进行循环
        data, target = data.clone().detach().requires_grad_(True), target.clone().detach() #data为图像，target为标签
        net.train() # 给网络模型做标记，标志说模型在训练集上训练
        output = net(data) #完成一次预测
        loss = criterion(output, target) #计算误差
        optimizer.zero_grad() #清空梯度
        loss.backward() #反向传播
        optimizer.step() #一步随机梯度下降
        right = rightness(output, target) #计算准确率所需数值，返回正确的数值为（正确样例数，总样本数）
        train_rights.append(right) #将计算结果装到列表容器中

    
        if batch_idx % 100 == 0: #每间隔100个batch执行一次
            
            #train_r为一个二元组，分别记录训练集中分类正确的数量和该集合中总的样本数
            train_r = (sum([tup[0] for tup in train_rights]), sum([tup[1] for tup in train_rights]))
            
            net.eval() # 给网络模型做标记，标志说模型在训练集上训练
            val_rights = [] #记录校验数据集准确率的容器
            for (data, target) in validation_loader:
                data, target = data.clone().detach().requires_grad_(True), target.clone().detach() 
                output = net(data) #完成一次预测
                right = rightness(output, target) #计算准确率所需数值，返回正确的数值为（正确样例数，总样本数）
                val_rights.append(right)
            
            #val_r为一个二元组，分别记录校验集中分类正确的数量和该集合中总的样本数
            val_r = (sum([tup[0] for tup in val_rights]), sum([tup[1] for tup in val_rights]))
            
            #打印准确率等数值，其中正确率为本训练周期Epoch开始后到目前撮的正确率的平均值
            print('训练周期: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}\t训练正确率: {:.2f}%\t校验正确率: {:.2f}%'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader),
                loss.data, 
                100. * train_r[0].numpy() / train_r[1], 
                100. * val_r[0].numpy() / val_r[1]))
            
            #将准确率和权重等数值加载到容器中，以方便后续处理
            record.append((100 - 100. * train_r[0].numpy() / train_r[1], 100 - 100. * val_r[0].numpy() / val_r[1]))
            weights.append([net.conv1.weight.data.clone(), net.conv1.bias.data.clone(), 
                            net.conv2.weight.data.clone(), net.conv2.bias.data.clone()])
# Out:
# 训练周期: 0 [0/60000 (0%)]	Loss: 2.300318	训练正确率: 6.25%	校验正确率: 10.26%
# 训练周期: 0 [800/60000 (11%)]	Loss: 2.285921	训练正确率: 10.35%	校验正确率: 10.26%
# 训练周期: 0 [1600/60000 (21%)]	Loss: 2.300794	训练正确率: 11.96%	校验正确率: 10.26%
# 训练周期: 0 [2400/60000 (32%)]	Loss: 2.276004	训练正确率: 13.31%	校验正确率: 17.28%
# 训练周期: 0 [3200/60000 (43%)]	Loss: 2.253486	训练正确率: 16.34%	校验正确率: 34.30%
# 训练周期: 0 [4000/60000 (53%)]	Loss: 2.110250	训练正确率: 20.64%	校验正确率: 52.86%
# 训练周期: 0 [4800/60000 (64%)]	Loss: 1.611243	训练正确率: 25.54%	校验正确率: 68.70%
# 训练周期: 0 [5600/60000 (75%)]	Loss: 0.700886	训练正确率: 31.47%	校验正确率: 80.66%
# 训练周期: 0 [6400/60000 (85%)]	Loss: 0.680414	训练正确率: 37.32%	校验正确率: 86.26%
# 训练周期: 0 [7200/60000 (96%)]	Loss: 0.492501	训练正确率: 42.35%	校验正确率: 88.14%
# 训练周期: 1 [0/60000 (0%)]	Loss: 0.420217	训练正确率: 89.06%	校验正确率: 88.94%
# 训练周期: 1 [800/60000 (11%)]	Loss: 0.437190	训练正确率: 86.70%	校验正确率: 90.26%
# 训练周期: 1 [1600/60000 (21%)]	Loss: 0.351464	训练正确率: 87.30%	校验正确率: 91.30%
# 训练周期: 1 [2400/60000 (32%)]	Loss: 0.388969	训练正确率: 87.80%	校验正确率: 91.52%
# 训练周期: 1 [3200/60000 (43%)]	Loss: 0.255989	训练正确率: 88.23%	校验正确率: 92.02%
# 训练周期: 1 [4000/60000 (53%)]	Loss: 0.244192	训练正确率: 88.78%	校验正确率: 92.80%
# 训练周期: 1 [4800/60000 (64%)]	Loss: 0.377811	训练正确率: 89.09%	校验正确率: 93.02%
# 训练周期: 1 [5600/60000 (75%)]	Loss: 0.362774	训练正确率: 89.37%	校验正确率: 93.18%
# 训练周期: 1 [6400/60000 (85%)]	Loss: 0.183523	训练正确率: 89.68%	校验正确率: 93.96%
# 训练周期: 1 [7200/60000 (96%)]	Loss: 0.176437	训练正确率: 90.00%	校验正确率: 93.80%
# 训练周期: 2 [0/60000 (0%)]	Loss: 0.313171	训练正确率: 89.06%	校验正确率: 94.26%
# 训练周期: 2 [800/60000 (11%)]	Loss: 0.125598	训练正确率: 92.90%	校验正确率: 94.28%
# 训练周期: 2 [1600/60000 (21%)]	Loss: 0.176990	训练正确率: 93.13%	校验正确率: 94.70%
# 训练周期: 2 [2400/60000 (32%)]	Loss: 0.150398	训练正确率: 93.02%	校验正确率: 95.10%
# 训练周期: 2 [3200/60000 (43%)]	Loss: 0.275599	训练正确率: 93.25%	校验正确率: 95.18%
# 训练周期: 2 [4000/60000 (53%)]	Loss: 0.263111	训练正确率: 93.44%	校验正确率: 95.26%
# 训练周期: 2 [4800/60000 (64%)]	Loss: 0.111309	训练正确率: 93.56%	校验正确率: 95.46%
# 训练周期: 2 [5600/60000 (75%)]	Loss: 0.151838	训练正确率: 93.66%	校验正确率: 95.60%
# 训练周期: 2 [6400/60000 (85%)]	Loss: 0.205347	训练正确率: 93.75%	校验正确率: 95.52%
# 训练周期: 2 [7200/60000 (96%)]	Loss: 0.206178	训练正确率: 93.82%	校验正确率: 95.66%
# 训练周期: 3 [0/60000 (0%)]	Loss: 0.219677	训练正确率: 95.31%	校验正确率: 95.84%
# 训练周期: 3 [800/60000 (11%)]	Loss: 0.106035	训练正确率: 95.24%	校验正确率: 95.74%
# 训练周期: 3 [1600/60000 (21%)]	Loss: 0.125502	训练正确率: 95.06%	校验正确率: 96.00%
# 训练周期: 3 [2400/60000 (32%)]	Loss: 0.150681	训练正确率: 94.92%	校验正确率: 96.18%
# 训练周期: 3 [3200/60000 (43%)]	Loss: 0.113127	训练正确率: 95.07%	校验正确率: 96.40%
# 训练周期: 3 [4000/60000 (53%)]	Loss: 0.093831	训练正确率: 95.01%	校验正确率: 96.48%
# 训练周期: 3 [4800/60000 (64%)]	Loss: 0.090721	训练正确率: 95.08%	校验正确率: 96.34%
# 训练周期: 3 [5600/60000 (75%)]	Loss: 0.158075	训练正确率: 95.21%	校验正确率: 96.34%
# 训练周期: 3 [6400/60000 (85%)]	Loss: 0.068516	训练正确率: 95.27%	校验正确率: 96.74%
# 训练周期: 3 [7200/60000 (96%)]	Loss: 0.176403	训练正确率: 95.36%	校验正确率: 96.60%
# 训练周期: 4 [0/60000 (0%)]	Loss: 0.055999	训练正确率: 98.44%	校验正确率: 96.74%
# 训练周期: 4 [800/60000 (11%)]	Loss: 0.244356	训练正确率: 95.99%	校验正确率: 96.52%
# 训练周期: 4 [1600/60000 (21%)]	Loss: 0.086658	训练正确率: 95.80%	校验正确率: 96.62%
# 训练周期: 4 [2400/60000 (32%)]	Loss: 0.238338	训练正确率: 95.78%	校验正确率: 96.92%
# 训练周期: 4 [3200/60000 (43%)]	Loss: 0.229775	训练正确率: 95.82%	校验正确率: 96.98%
# 训练周期: 4 [4000/60000 (53%)]	Loss: 0.154019	训练正确率: 95.95%	校验正确率: 97.22%
# 训练周期: 4 [4800/60000 (64%)]	Loss: 0.131795	训练正确率: 95.98%	校验正确率: 97.12%
# 训练周期: 4 [5600/60000 (75%)]	Loss: 0.165775	训练正确率: 95.98%	校验正确率: 97.10%
# 训练周期: 4 [6400/60000 (85%)]	Loss: 0.149872	训练正确率: 96.04%	校验正确率: 97.28%
# 训练周期: 4 [7200/60000 (96%)]	Loss: 0.137341	训练正确率: 96.10%	校验正确率: 97.24%
# 训练周期: 5 [0/60000 (0%)]	Loss: 0.083661	训练正确率: 96.88%	校验正确率: 97.34%
# 训练周期: 5 [800/60000 (11%)]	Loss: 0.025153	训练正确率: 96.47%	校验正确率: 97.40%
# 训练周期: 5 [1600/60000 (21%)]	Loss: 0.088237	训练正确率: 96.23%	校验正确率: 97.30%
# 训练周期: 5 [2400/60000 (32%)]	Loss: 0.126444	训练正确率: 96.16%	校验正确率: 97.50%
# 训练周期: 5 [3200/60000 (43%)]	Loss: 0.044320	训练正确率: 96.27%	校验正确率: 97.40%
# 训练周期: 5 [4000/60000 (53%)]	Loss: 0.067405	训练正确率: 96.41%	校验正确率: 97.48%
# 训练周期: 5 [4800/60000 (64%)]	Loss: 0.195528	训练正确率: 96.44%	校验正确率: 97.44%
# 训练周期: 5 [5600/60000 (75%)]	Loss: 0.109746	训练正确率: 96.43%	校验正确率: 97.70%
# 训练周期: 5 [6400/60000 (85%)]	Loss: 0.071657	训练正确率: 96.48%	校验正确率: 97.64%
# 训练周期: 5 [7200/60000 (96%)]	Loss: 0.116572	训练正确率: 96.52%	校验正确率: 97.72%
# 训练周期: 6 [0/60000 (0%)]	Loss: 0.051099	训练正确率: 100.00%	校验正确率: 97.64%
# 训练周期: 6 [800/60000 (11%)]	Loss: 0.160353	训练正确率: 97.28%	校验正确率: 97.72%
# 训练周期: 6 [1600/60000 (21%)]	Loss: 0.164595	训练正确率: 97.11%	校验正确率: 97.80%
# 训练周期: 6 [2400/60000 (32%)]	Loss: 0.122188	训练正确率: 97.09%	校验正确率: 97.70%
# 训练周期: 6 [3200/60000 (43%)]	Loss: 0.167349	训练正确率: 96.99%	校验正确率: 97.80%
# 训练周期: 6 [4000/60000 (53%)]	Loss: 0.164310	训练正确率: 96.94%	校验正确率: 97.70%
# 训练周期: 6 [4800/60000 (64%)]	Loss: 0.051449	训练正确率: 96.95%	校验正确率: 97.80%
# 训练周期: 6 [5600/60000 (75%)]	Loss: 0.138217	训练正确率: 96.98%	校验正确率: 97.72%
# 训练周期: 6 [6400/60000 (85%)]	Loss: 0.068587	训练正确率: 96.96%	校验正确率: 97.82%
# 训练周期: 6 [7200/60000 (96%)]	Loss: 0.177880	训练正确率: 96.95%	校验正确率: 97.86%
# 训练周期: 7 [0/60000 (0%)]	Loss: 0.064762	训练正确率: 100.00%	校验正确率: 97.92%
# 训练周期: 7 [800/60000 (11%)]	Loss: 0.098034	训练正确率: 97.17%	校验正确率: 97.90%
# 训练周期: 7 [1600/60000 (21%)]	Loss: 0.040994	训练正确率: 97.26%	校验正确率: 97.86%
# 训练周期: 7 [2400/60000 (32%)]	Loss: 0.027720	训练正确率: 97.29%	校验正确率: 97.84%
# 训练周期: 7 [3200/60000 (43%)]	Loss: 0.053579	训练正确率: 97.37%	校验正确率: 97.80%
# 训练周期: 7 [4000/60000 (53%)]	Loss: 0.154079	训练正确率: 97.23%	校验正确率: 97.76%
# 训练周期: 7 [4800/60000 (64%)]	Loss: 0.135953	训练正确率: 97.29%	校验正确率: 97.96%
# 训练周期: 7 [5600/60000 (75%)]	Loss: 0.055542	训练正确率: 97.28%	校验正确率: 97.96%
# 训练周期: 7 [6400/60000 (85%)]	Loss: 0.311460	训练正确率: 97.26%	校验正确率: 98.06%
# 训练周期: 7 [7200/60000 (96%)]	Loss: 0.057538	训练正确率: 97.25%	校验正确率: 98.08%
# 训练周期: 8 [0/60000 (0%)]	Loss: 0.164556	训练正确率: 93.75%	校验正确率: 98.02%
# 训练周期: 8 [800/60000 (11%)]	Loss: 0.070673	训练正确率: 97.54%	校验正确率: 98.18%
# 训练周期: 8 [1600/60000 (21%)]	Loss: 0.151881	训练正确率: 97.40%	校验正确率: 98.20%
# 训练周期: 8 [2400/60000 (32%)]	Loss: 0.064701	训练正确率: 97.35%	校验正确率: 98.00%
# 训练周期: 8 [3200/60000 (43%)]	Loss: 0.198425	训练正确率: 97.40%	校验正确率: 98.16%
# 训练周期: 8 [4000/60000 (53%)]	Loss: 0.243029	训练正确率: 97.42%	校验正确率: 98.00%
# 训练周期: 8 [4800/60000 (64%)]	Loss: 0.103368	训练正确率: 97.36%	校验正确率: 98.00%
# 训练周期: 8 [5600/60000 (75%)]	Loss: 0.104183	训练正确率: 97.38%	校验正确率: 98.14%
# 训练周期: 8 [6400/60000 (85%)]	Loss: 0.169861	训练正确率: 97.40%	校验正确率: 98.28%
# 训练周期: 8 [7200/60000 (96%)]	Loss: 0.084714	训练正确率: 97.44%	校验正确率: 98.02%
# 训练周期: 9 [0/60000 (0%)]	Loss: 0.111912	训练正确率: 96.88%	校验正确率: 98.20%
# 训练周期: 9 [800/60000 (11%)]	Loss: 0.121354	训练正确率: 97.17%	校验正确率: 98.12%
# 训练周期: 9 [1600/60000 (21%)]	Loss: 0.037942	训练正确率: 97.18%	校验正确率: 98.22%
# 训练周期: 9 [2400/60000 (32%)]	Loss: 0.107380	训练正确率: 97.39%	校验正确率: 98.24%
# 训练周期: 9 [3200/60000 (43%)]	Loss: 0.081619	训练正确率: 97.48%	校验正确率: 98.06%
# 训练周期: 9 [4000/60000 (53%)]	Loss: 0.069744	训练正确率: 97.52%	校验正确率: 98.20%
# 训练周期: 9 [4800/60000 (64%)]	Loss: 0.113999	训练正确率: 97.55%	校验正确率: 98.00%
# 训练周期: 9 [5600/60000 (75%)]	Loss: 0.025453	训练正确率: 97.57%	校验正确率: 98.20%
# 训练周期: 9 [6400/60000 (85%)]	Loss: 0.050103	训练正确率: 97.56%	校验正确率: 98.32%
# 训练周期: 9 [7200/60000 (96%)]	Loss: 0.021131	训练正确率: 97.57%	校验正确率: 98.28%
# 训练周期: 10 [0/60000 (0%)]	Loss: 0.045255	训练正确率: 98.44%	校验正确率: 98.18%
# 训练周期: 10 [800/60000 (11%)]	Loss: 0.044297	训练正确率: 97.63%	校验正确率: 98.32%
# 训练周期: 10 [1600/60000 (21%)]	Loss: 0.030701	训练正确率: 97.80%	校验正确率: 98.28%
# 训练周期: 10 [2400/60000 (32%)]	Loss: 0.124644	训练正确率: 97.65%	校验正确率: 98.30%
# 训练周期: 10 [3200/60000 (43%)]	Loss: 0.103252	训练正确率: 97.72%	校验正确率: 98.28%
# 训练周期: 10 [4000/60000 (53%)]	Loss: 0.029638	训练正确率: 97.71%	校验正确率: 98.24%
# 训练周期: 10 [4800/60000 (64%)]	Loss: 0.060597	训练正确率: 97.70%	校验正确率: 98.40%
# 训练周期: 10 [5600/60000 (75%)]	Loss: 0.020122	训练正确率: 97.72%	校验正确率: 98.32%
# 训练周期: 10 [6400/60000 (85%)]	Loss: 0.023521	训练正确率: 97.74%	校验正确率: 98.20%
# 训练周期: 10 [7200/60000 (96%)]	Loss: 0.017205	训练正确率: 97.75%	校验正确率: 98.38%
# 训练周期: 11 [0/60000 (0%)]	Loss: 0.235748	训练正确率: 93.75%	校验正确率: 98.48%
# 训练周期: 11 [800/60000 (11%)]	Loss: 0.028075	训练正确率: 97.59%	校验正确率: 98.46%
# 训练周期: 11 [1600/60000 (21%)]	Loss: 0.045871	训练正确率: 97.77%	校验正确率: 98.52%
# 训练周期: 11 [2400/60000 (32%)]	Loss: 0.110833	训练正确率: 97.77%	校验正确率: 98.40%
# 训练周期: 11 [3200/60000 (43%)]	Loss: 0.023720	训练正确率: 97.81%	校验正确率: 98.52%
# 训练周期: 11 [4000/60000 (53%)]	Loss: 0.074590	训练正确率: 97.79%	校验正确率: 98.26%
# 训练周期: 11 [4800/60000 (64%)]	Loss: 0.047962	训练正确率: 97.73%	校验正确率: 98.30%
# 训练周期: 11 [5600/60000 (75%)]	Loss: 0.042145	训练正确率: 97.76%	校验正确率: 98.42%
# 训练周期: 11 [6400/60000 (85%)]	Loss: 0.024274	训练正确率: 97.78%	校验正确率: 98.58%
# 训练周期: 11 [7200/60000 (96%)]	Loss: 0.090142	训练正确率: 97.77%	校验正确率: 98.52%
# 训练周期: 12 [0/60000 (0%)]	Loss: 0.109454	训练正确率: 95.31%	校验正确率: 98.38%
# 训练周期: 12 [800/60000 (11%)]	Loss: 0.071421	训练正确率: 97.51%	校验正确率: 98.20%
# 训练周期: 12 [1600/60000 (21%)]	Loss: 0.108155	训练正确率: 97.68%	校验正确率: 98.38%
# 训练周期: 12 [2400/60000 (32%)]	Loss: 0.024596	训练正确率: 97.78%	校验正确率: 98.58%
# 训练周期: 12 [3200/60000 (43%)]	Loss: 0.051535	训练正确率: 97.83%	校验正确率: 98.44%
# 训练周期: 12 [4000/60000 (53%)]	Loss: 0.037716	训练正确率: 97.85%	校验正确率: 98.38%
# 训练周期: 12 [4800/60000 (64%)]	Loss: 0.053940	训练正确率: 97.86%	校验正确率: 98.66%
# 训练周期: 12 [5600/60000 (75%)]	Loss: 0.100030	训练正确率: 97.88%	校验正确率: 98.58%
# 训练周期: 12 [6400/60000 (85%)]	Loss: 0.029533	训练正确率: 97.90%	校验正确率: 98.54%
# 训练周期: 12 [7200/60000 (96%)]	Loss: 0.100772	训练正确率: 97.90%	校验正确率: 98.68%
# 训练周期: 13 [0/60000 (0%)]	Loss: 0.095479	训练正确率: 98.44%	校验正确率: 98.66%
# 训练周期: 13 [800/60000 (11%)]	Loss: 0.066705	训练正确率: 98.00%	校验正确率: 98.60%
# 训练周期: 13 [1600/60000 (21%)]	Loss: 0.002748	训练正确率: 98.09%	校验正确率: 98.68%
# 训练周期: 13 [2400/60000 (32%)]	Loss: 0.124144	训练正确率: 98.12%	校验正确率: 98.52%
# 训练周期: 13 [3200/60000 (43%)]	Loss: 0.041189	训练正确率: 98.06%	校验正确率: 98.52%
# 训练周期: 13 [4000/60000 (53%)]	Loss: 0.101547	训练正确率: 98.10%	校验正确率: 98.50%
# 训练周期: 13 [4800/60000 (64%)]	Loss: 0.191586	训练正确率: 98.06%	校验正确率: 98.74%
# 训练周期: 13 [5600/60000 (75%)]	Loss: 0.011135	训练正确率: 98.05%	校验正确率: 98.50%
# 训练周期: 13 [6400/60000 (85%)]	Loss: 0.032823	训练正确率: 98.03%	校验正确率: 98.68%
# 训练周期: 13 [7200/60000 (96%)]	Loss: 0.106877	训练正确率: 98.03%	校验正确率: 98.52%
# 训练周期: 14 [0/60000 (0%)]	Loss: 0.064597	训练正确率: 96.88%	校验正确率: 98.44%
# 训练周期: 14 [800/60000 (11%)]	Loss: 0.130233	训练正确率: 98.25%	校验正确率: 98.66%
# 训练周期: 14 [1600/60000 (21%)]	Loss: 0.113685	训练正确率: 98.17%	校验正确率: 98.62%
# 训练周期: 14 [2400/60000 (32%)]	Loss: 0.067791	训练正确率: 98.05%	校验正确率: 98.64%
# 训练周期: 14 [3200/60000 (43%)]	Loss: 0.028793	训练正确率: 98.03%	校验正确率: 98.68%
# 训练周期: 14 [4000/60000 (53%)]	Loss: 0.126222	训练正确率: 98.04%	校验正确率: 98.76%
# 训练周期: 14 [4800/60000 (64%)]	Loss: 0.097307	训练正确率: 98.01%	校验正确率: 98.76%
# 训练周期: 14 [5600/60000 (75%)]	Loss: 0.029519	训练正确率: 98.05%	校验正确率: 98.66%
# 训练周期: 14 [6400/60000 (85%)]	Loss: 0.088575	训练正确率: 98.07%	校验正确率: 98.54%
# 训练周期: 14 [7200/60000 (96%)]	Loss: 0.159710	训练正确率: 98.05%	校验正确率: 98.60%
# 训练周期: 15 [0/60000 (0%)]	Loss: 0.035221	训练正确率: 98.44%	校验正确率: 98.76%
# 训练周期: 15 [800/60000 (11%)]	Loss: 0.036796	训练正确率: 98.28%	校验正确率: 98.72%
# 训练周期: 15 [1600/60000 (21%)]	Loss: 0.047097	训练正确率: 98.25%	校验正确率: 98.64%
# 训练周期: 15 [2400/60000 (32%)]	Loss: 0.016952	训练正确率: 98.29%	校验正确率: 98.56%
# 训练周期: 15 [3200/60000 (43%)]	Loss: 0.027372	训练正确率: 98.26%	校验正确率: 98.76%
# 训练周期: 15 [4000/60000 (53%)]	Loss: 0.231788	训练正确率: 98.20%	校验正确率: 98.78%
# 训练周期: 15 [4800/60000 (64%)]	Loss: 0.091569	训练正确率: 98.18%	校验正确率: 98.68%
# 训练周期: 15 [5600/60000 (75%)]	Loss: 0.012676	训练正确率: 98.15%	校验正确率: 98.72%
# 训练周期: 15 [6400/60000 (85%)]	Loss: 0.075833	训练正确率: 98.19%	校验正确率: 98.76%
# 训练周期: 15 [7200/60000 (96%)]	Loss: 0.026988	训练正确率: 98.18%	校验正确率: 98.80%
# 训练周期: 16 [0/60000 (0%)]	Loss: 0.071547	训练正确率: 96.88%	校验正确率: 98.72%
# 训练周期: 16 [800/60000 (11%)]	Loss: 0.086741	训练正确率: 98.14%	校验正确率: 98.76%
# 训练周期: 16 [1600/60000 (21%)]	Loss: 0.017533	训练正确率: 98.36%	校验正确率: 98.68%
# 训练周期: 16 [2400/60000 (32%)]	Loss: 0.017385	训练正确率: 98.25%	校验正确率: 98.82%
# 训练周期: 16 [3200/60000 (43%)]	Loss: 0.193270	训练正确率: 98.27%	校验正确率: 98.60%
# 训练周期: 16 [4000/60000 (53%)]	Loss: 0.007889	训练正确率: 98.26%	校验正确率: 98.86%
# 训练周期: 16 [4800/60000 (64%)]	Loss: 0.158951	训练正确率: 98.26%	校验正确率: 98.82%
# 训练周期: 16 [5600/60000 (75%)]	Loss: 0.043684	训练正确率: 98.31%	校验正确率: 98.92%
# 训练周期: 16 [6400/60000 (85%)]	Loss: 0.102962	训练正确率: 98.30%	校验正确率: 98.88%
# 训练周期: 16 [7200/60000 (96%)]	Loss: 0.106286	训练正确率: 98.31%	校验正确率: 98.72%
# 训练周期: 17 [0/60000 (0%)]	Loss: 0.031680	训练正确率: 100.00%	校验正确率: 98.68%
# 训练周期: 17 [800/60000 (11%)]	Loss: 0.203716	训练正确率: 98.39%	校验正确率: 98.88%
# 训练周期: 17 [1600/60000 (21%)]	Loss: 0.169103	训练正确率: 98.44%	校验正确率: 98.76%
# 训练周期: 17 [2400/60000 (32%)]	Loss: 0.008223	训练正确率: 98.42%	校验正确率: 98.96%
# 训练周期: 17 [3200/60000 (43%)]	Loss: 0.121676	训练正确率: 98.36%	校验正确率: 98.70%
# 训练周期: 17 [4000/60000 (53%)]	Loss: 0.074871	训练正确率: 98.34%	校验正确率: 98.92%
# 训练周期: 17 [4800/60000 (64%)]	Loss: 0.062241	训练正确率: 98.31%	校验正确率: 98.56%
# 训练周期: 17 [5600/60000 (75%)]	Loss: 0.079530	训练正确率: 98.28%	校验正确率: 98.92%
# 训练周期: 17 [6400/60000 (85%)]	Loss: 0.078208	训练正确率: 98.28%	校验正确率: 98.90%
# 训练周期: 17 [7200/60000 (96%)]	Loss: 0.055116	训练正确率: 98.30%	校验正确率: 98.90%
# 训练周期: 18 [0/60000 (0%)]	Loss: 0.073238	训练正确率: 98.44%	校验正确率: 98.78%
# 训练周期: 18 [800/60000 (11%)]	Loss: 0.030276	训练正确率: 98.25%	校验正确率: 98.86%
# 训练周期: 18 [1600/60000 (21%)]	Loss: 0.019588	训练正确率: 98.39%	校验正确率: 98.74%
# 训练周期: 18 [2400/60000 (32%)]	Loss: 0.120438	训练正确率: 98.26%	校验正确率: 98.92%
# 训练周期: 18 [3200/60000 (43%)]	Loss: 0.033063	训练正确率: 98.31%	校验正确率: 98.84%
# 训练周期: 18 [4000/60000 (53%)]	Loss: 0.058542	训练正确率: 98.32%	校验正确率: 98.82%
# 训练周期: 18 [4800/60000 (64%)]	Loss: 0.023495	训练正确率: 98.30%	校验正确率: 98.82%
# 训练周期: 18 [5600/60000 (75%)]	Loss: 0.085723	训练正确率: 98.32%	校验正确率: 98.82%
# 训练周期: 18 [6400/60000 (85%)]	Loss: 0.056804	训练正确率: 98.33%	校验正确率: 98.82%
# 训练周期: 18 [7200/60000 (96%)]	Loss: 0.027189	训练正确率: 98.34%	校验正确率: 98.90%
# 训练周期: 19 [0/60000 (0%)]	Loss: 0.037896	训练正确率: 98.44%	校验正确率: 98.88%
# 训练周期: 19 [800/60000 (11%)]	Loss: 0.098254	训练正确率: 98.34%	校验正确率: 98.84%
# 训练周期: 19 [1600/60000 (21%)]	Loss: 0.046797	训练正确率: 98.39%	校验正确率: 98.86%
# 训练周期: 19 [2400/60000 (32%)]	Loss: 0.073712	训练正确率: 98.28%	校验正确率: 98.64%
# 训练周期: 19 [3200/60000 (43%)]	Loss: 0.009204	训练正确率: 98.31%	校验正确率: 99.00%
# 训练周期: 19 [4000/60000 (53%)]	Loss: 0.026287	训练正确率: 98.34%	校验正确率: 98.92%
# 训练周期: 19 [4800/60000 (64%)]	Loss: 0.006523	训练正确率: 98.39%	校验正确率: 98.94%
# 训练周期: 19 [5600/60000 (75%)]	Loss: 0.027071	训练正确率: 98.43%	校验正确率: 98.76%
# 训练周期: 19 [6400/60000 (85%)]	Loss: 0.020236	训练正确率: 98.41%	校验正确率: 98.86%
# 训练周期: 19 [7200/60000 (96%)]	Loss: 0.133386	训练正确率: 98.42%	校验正确率: 98.82%

# %% [markdown]
# ## 保存模型

# %%
# 在这里保存已经训练好的神经网络
torch.save(net, 'minst_conv_checkpoint') #后面的字符串为保存文件的路径

# %%
#提取第一层卷积层的卷积核
plt.figure(figsize = (10, 7))
for i in range(4):
    plt.subplot(1,4,i + 1)
    plt.imshow(net.conv1.weight.data.numpy()[i,0,...])

# %%
# 绘制第二层的卷积核
plt.figure(figsize = (15, 10))
for i in range(4):
    for j in range(8):
        plt.subplot(4, 8, i * 8 + j + 1)
        plt.imshow(net.conv2.weight.data.numpy()[j, i,...])
